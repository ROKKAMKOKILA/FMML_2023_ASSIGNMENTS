# %% [markdown]
# <a href="https://colab.research.google.com/github/ROKKAMKOKILA/FMML_2023_ASSIGNMENTS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-30 06:06:42--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json.1’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   136MB/s    in 0.5s
#
# 2024-03-30 06:06:43 (136 MB/s) - ‘arxiv-paper-data.json.1’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22788  1706.08495v2  Bayesian neural networks (BNNs) with latent va...  stat
# 25283  1507.02438v1  Several state-of-the-art video deblurring meth...    cs
# 27420  1703.06256v1  The histogram of oriented gradients (HOG) is a...    cs
# 36138   1207.1016v1  Evidential grids have been recently used for m...    cs
# 16870  1706.09799v1  Automated metrics such as BLEU are widely used...    cs
# ...             ...                                                ...   ...
# 35252  cs/0206004v1  Recent studies on frequent itemset mining algo...    cs
# 12595  1803.03919v1  We propose a nonparametric method for detectin...  stat
# 34687  1709.05467v1  In this paper, we address the problem of detec...    cs
# 3415   1702.07959v3  We introduce a new algorithm, called CDER, for...    cs
# 11791  1701.05363v3  We present a matrix-factorization algorithm th...  stat
#
#                                                    title  year  \
# 22788  Uncertainty Decomposition in Bayesian Neural N...  2017
# 25283    Generalized Video Deblurring for Dynamic Scenes  2015
# 27420  A Fast HOG Descriptor Using Lookup Table and I...  2017
# 36138  Map-aided Fusion Using Evidential Grids for Mo...  2012
# 16870  Relevance of Unsupervised Metrics in Task-Orie...  2017
# ...                                                  ...   ...
# 35252         Mining All Non-Derivable Frequent Itemsets  2002
# 12595  Detecting Nonlinear Causality in Multivariate ...  2018
# 34687  Acquiring Background Knowledge to Improve Mora...  2017
# 3415   Supervised Learning of Labeled Pointcloud Diff...  2017
# 11791  Stochastic Subsampling for Factorizing Huge Ma...  2017
#
#                                                 keywords
# 22788  [variables, probabilistic, automatically, stoc...
# 25283  [deblurring, assumption, deblurring, variation...
# 27420  [histogram, gradients, descriptor, detection, ...
# 36138  [evidential, perception, perception, knowledge...
# 16870  [automated, translation, literature, community...
# ...                                                  ...
# 35252  [algorithms, significant, performance, improve...
# 12595  [nonparametric, detecting, nonlinear, relation...
# 34687  [detecting, expressions, particularly, challen...
# 3415   [introduce, algorithm, supervised, geometric, ...
# 11791  [factorization, algorithm, algorithm, dictiona...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22788    [variables, probabilistic, automatically, stoc...
# 25283    [deblurring, assumption, deblurring, variation...
# 27420    [histogram, gradients, descriptor, detection, ...
# 36138    [evidential, perception, perception, knowledge...
# 16870    [automated, translation, literature, community...
#                                ...
# 32676    [discusses, comparing, clusterings, motivation...
# 2853     [advertising, advertisers, impression, maximiz...
# 14729    [challenges, development, deployment, generati...
# 2257     [difference, important, reinforcement, algorit...
# 18698    [combinatorial, optimization, assigning, conta...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8783 words.
# Out of those 4502 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a3a4a3ef-21d9-4909-ade6-b268e4d8c561" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3a4a3ef-21d9-4909-ade6-b268e4d8c561")) {                    Plotly.newPlot(                        "a3a4a3ef-21d9-4909-ade6-b268e4d8c561",                        [{"x":["illustrate","components","objective","predictive","decomposition","uncertainty","minimizes","information","stochastic","reinforcement","aleatoric","sensitive","probabilistic","variables","epistemic","resulting","theoretic","described","usefulness","automatically","naturally","environments","following","experiments","challenging","estimating","extensive","significant","bidirectional","experimental","assumption","estimates","demonstrate","simultaneously","efficient","superiority","approximate","estimation","improvements","variation","minimizing","deblurring","therefore","generalized","framework","improvement","descriptor","performance","gradients","exploiting","detection","histogram","distinguish","introduced","environment","different","geographic","representing","discounting","perception","considered","evidential","contextual","stationary","additional","knowledge","presented","diversity","correlate","available","responses","reference","judgments","evaluating","correlation","currently","generation","translating","sentences","unsupervised","community","reasonable","relevance","expressed","empirical","translation","literature","automated","generalizing","algorithm","functions","optimality","regression","architecture","highlight","indication","measurements","annotations","applications","registered","introduce","integrates","interaction","attention","semantics","predicting","important","empirically","projection","corresponding","trainable","characterization","convolutional","diagnosis","attributes","significance","treatment","augmentation","calcification","establish","determination","appearance","intensity","malignant","concatenated","complementary","dimension","relationship","relations","penalizing","alleviate","technique","computing","limitation","transformations","multivariate","canonical","regularization","statistical","generalization","nonlinear","posterior","approximation","integrated","restricted","differential","distribution","analytically","intractable","advantage","themselves","equations","derivatives","including","determine","promising","processes","variational","tractable","distributed","integrating","contaminated","parameters","observations","facilitate","posteriori","inference","constraint","accurately","performed","consensus","reconstruction","estimated","necessary","comprises","clustering","constraints","localization","extracted","dimensional","reconstruct","extraction","iterative","procedure","promoting","coordinate","regularized","demonstrating","diameters","computations","particular","optimization","multinomial","screening","spherical","regularizations","enforcement","dependencies","relatively","supported"],"y":[71,114,167,66,60,64,18,705,125,122,0,42,169,120,8,132,44,66,34,181,63,78,70,595,247,68,163,234,26,366,80,73,552,127,368,41,102,228,105,61,66,14,133,77,555,148,28,877,32,87,362,28,37,116,113,737,7,73,5,33,127,6,47,22,96,326,185,36,11,304,29,55,10,59,78,64,162,19,71,149,78,27,32,36,160,115,124,109,15,803,208,13,128,236,33,6,70,65,436,9,341,30,74,175,117,84,362,79,44,134,24,37,366,49,57,20,41,18,2,33,9,70,39,3,6,42,73,80,90,3,25,244,119,16,36,22,18,90,160,123,49,32,130,62,53,26,219,13,24,86,25,27,14,260,72,107,110,57,37,109,34,4,249,76,42,6,224,81,63,138,10,106,55,59,18,135,130,54,98,194,34,141,70,118,4,28,41,36,1,33,286,300,7,5,9,0,5,48,62,21],"type":"bar"},{"x":["illustrate","components","objective","predictive","decomposition","uncertainty","mini ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4502,), (4502, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8025

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Exploiting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Unlabeled</span> <span style=''>Data</span> <span style=''>for</span> <span style=''>Neural</span> <span style='background-color:rgba(0, 255, 0, 0.8823529411764706);'>Grammatical</span> <span style=''>Error</span> <span style='background-color:rgba(0, 255, 0, 0.553648068669528);'>Detection</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Identifying</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correcting</span> <span style='background-color:rgba(0, 255, 0, 0.8823529411764706);'>grammatical</span> <span style=''>errors</span> <span style=''>in</span> <span style=''>the</span> <span style=''>text</span> <span style=''>written</span> <span style=''>by</span> <span style=''>non</span> <span style=''>native</span> <span style=''>writers</span> <span style=''>has</span> <span style=''>received</span> <span style='background-color:rgba(0, 255, 0, 0.35955056179775285);'>increasing</span> <span style='background-color:rgba(0, 255, 0, 0.37795275590551175);'>attention</span> <span style=''>in</span> <span style=''>recent</span> <span style=''>years</span> <span style=''>Although</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.8333333333333334);'>annotated</span> <span style=''>corpora</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>established</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3770491803278689);'>facilitate</span> <span style=''>data</span> <span style=''>driven</span> <span style='background-color:rgba(0, 255, 0, 0.8823529411764706);'>grammatical</span> <span style=''>error</span> <span style='background-color:rgba(0, 255, 0, 0.553648068669528);'>detection</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correction</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>they</span> <span style=''>are</span> <span style=''>still</span> <span style=''>limited</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>quantity</span> <span style=''>and</span> <span style=''>coverage</span> <span style=''>because</span> <span style=''>human</span> <span style='background-color:rgba(0, 255, 0, 0.7297297297297296);'>annotation</span> <span style=''>is</span> <span style=''>labor</span> <span style='background-color:rgba(0, 255, 0, 0.3181818181818181);'>intensive</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consuming</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expensive</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>utilize</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unlabeled</span> <span style=''>data</span> <span style=''>to</span> <span style=''>train</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.8823529411764706);'>grammatical</span> <span style=''>error</span> <span style='background-color:rgba(0, 255, 0, 0.553648068669528);'>detection</span> <span style=''>models</span> <span style=''>The</span> <span style=''>basic</span> <span style=''>idea</span> <span style=''>is</span> <span style=''>to</span> <span style=''>cast</span> <span style=''>error</span> <span style='background-color:rgba(0, 255, 0, 0.553648068669528);'>detection</span> <span style=''>as</span> <span style=''>a</span> <span style=''>binary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>problem</span> <span styl ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Transfer</span> <span style=''>Learning</span> <span style=''>Across</span> <span style=''>Patient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Variations</span> <span style=''>with</span> <span style=''>Hidden</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Parameter</span> <span style=''>Markov</span> <span style=''>Decision</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Processes</span> <br/><br/><span style=''>Due</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>physiological</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>variation</span> <span style=''>patients</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>diagnosed</span> <span style=''>with</span> <span style=''>the</span> <span style=''>same</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>condition</span> <span style=''>may</span> <span style=''>exhibit</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>divergent</span> <span style=''>but</span> <span style=''>related</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>responses</span> <span style=''>to</span> <span style=''>the</span> <span style=''>same</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>treatments</span> <span style=''>Hidden</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Parameter</span> <span style=''>Markov</span> <span style=''>Decision</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Processes</span> <span style=''>(HiP</span> <span style=''>MDPs)</span> <span style=''>tackle</span> <span style=''>this</span> <span style=''>transfer</span> <span style=''>learning</span> <span style=''>problem</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style=''>these</span> <span style=''>tasks</span> <span style=''>into</span> <span style=''>a</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>space</span> <span style=''>However</span> <span style=''>the</span> <span style=''>original</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulation</span> <span style=''>of</span> <span style=''>HiP</span> <span style=''>MDP</span> <span style=''>had</span> <span style=''>a</span> <span style=''>critical</span> <span style=''>flaw</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>was</span> <span style=''>modeled</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independently</span> <span style=''>of</span> <span style=''>the</span> <span style=''>agents</span> <span style=''>state</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>requiring</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unnatural</span> <span style=''>training</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style=''>in</span> <span style=''>which</span> <span style=''>all</span> <span style=''>tasks</span> <span style=''>visited</span> <span style=''>every</span> <span style=''>part</span> <span style=''>of</span> <span style=''>the</span> <span style=''>state</span> <span style=''>space</span> <span style=''>possible</span> <span style=''>for</span> <span style=''>robots</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>moved</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>location</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>impossible</span> <span style=''>for</span> <span style=''>human</span> <span style=''>patients</span> <span style=''>We</span> <span style=''>update</s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Robust</span> <span style=''>Subspace</span> <span style=''>System</span> <span style='background-color:rgba(0, 255, 0, 0.33766233766233766);'>Identification</span> <span style=''>via</span> <span style=''>Weighted</span> <span style=''>Nuclear</span> <span style=''>Norm</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <br/><br/><span style=''>Subspace</span> <span style='background-color:rgba(0, 255, 0, 0.33766233766233766);'>identification</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classical</span> <span style=''>and</span> <span style=''>very</span> <span style=''>well</span> <span style=''>studied</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>system</span> <span style='background-color:rgba(0, 255, 0, 0.33766233766233766);'>identification</span> <span style=''>The</span> <span style=''>problem</span> <span style=''>was</span> <span style=''>recently</span> <span style=''>posed</span> <span style=''>as</span> <span style=''>a</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>via</span> <span style=''>the</span> <span style=''>nuclear</span> <span style=''>norm</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relaxation</span> <span style=''>Inspired</span> <span style=''>by</span> <span style=''>robust</span> <span style=''>PCA</span> <span style=''>we</span> <span style=''>extend</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>to</span> <span style=''>handle</span> <span style=''>outliers</span> <span style=''>The</span> <span style=''>proposed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>takes</span> <span style=''>the</span> <span style=''>form</span> <span style=''>of</span> <span style=''>a</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>with</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>that</span> <span style=''>trades</span> <span style=''>off</span> <span style=''>fit</span> <span style=''>rank</span> <span style=''>and</span> <span style=''>sparsity</span> <span style=''>As</span> <span style=''>in</span> <span style=''>robust</span> <span style=''>PCA</span> <span style=''>it</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>problematic</span> <span style=''>to</span> <span style=''>find</span> <span style=''>a</span> <span style=''>suitable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style=''>We</span> <span style=''>show</span> <span style=''>how</span> <span style=''>the</span> <span style=''>space</span> <span style=''>in</span> <span style=''>which</span> <span style=''>a</span> <span style=''>suitable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style=''>should</span> <span style=''>be</span> <span style=''>sought</span> <span style=''>can</span> <span style=''>be</span> <span style=''>limited</span> <span style=''>to</span> <span style=''>a</span> <span style=''>bounded</span> <span style=''>open</span> <span style=''>set</span> <span style=''>of</span> <span style=''>the</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3356164383561644);'>dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style=''>space</span> <span style=''>In</span> <span style=''>practice</span> <span style=''>this</span> <span style=''>is</span> <span style=''>very</span> <span style=''>useful</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Deep</span> <span style=''>Neural</span> <span style=''>Network</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Approximation</span> <span style=''>using</span> <span style=''>Tensor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Sketching</span> <br/><br/><span style=''>Deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>are</span> <span style=''>powerful</span> <span style=''>learning</span> <span style=''>models</span> <span style=''>that</span> <span style=''>achieve</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>on</span> <span style=''>many</span> <span style=''>computer</span> <span style=''>vision</span> <span style=''>speech</span> <span style=''>and</span> <span style=''>language</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>tasks</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>study</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>fundamental</span> <span style=''>question</span> <span style=''>that</span> <span style=''>arises</span> <span style=''>when</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>designing</span> <span style=''>deep</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architectures</span> <span style=''>Given</span> <span style=''>a</span> <span style=''>target</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architecture</span> <span style=''>can</span> <span style=''>we</span> <span style=''>design</span> <span style=''>a</span> <span style=''>smaller</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architecture</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximates</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>operation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>target</span> <span style=''>network</span> <span style=''>The</span> <span style=''>question</span> <span style=''>is</span> <span style=''>in</span> <span style=''>part</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>motivated</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenge</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>(compression)</span> <span style=''>in</span> <span style=''>modern</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>as</span> <span style=''>the</span> <span style=''>ever</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increasing</span> <span style=''>storage</span> <span style=''>and</span> <span style=''>memory</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>requirements</span> <span style=''>of</span> <span style=''>these</span> <span style=''>networks</span> <span style=''>pose</span> <span style=''>a</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>resource</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constrained</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>environments</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>deep</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convolutional</span> <span style=''>neural</span> <span style=''>network</span> <span style='background-color:rgba(255,  ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="01bc104d-8ede-4836-b0f5-c4cb62b65b82" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("01bc104d-8ede-4836-b0f5-c4cb62b65b82")) {                    Plotly.newPlot(                        "01bc104d-8ede-4836-b0f5-c4cb62b65b82",                        [{"x":["illustrate","components","objective","predictive","decomposition","uncertainty","minimizes","information","stochastic","reinforcement","aleatoric","sensitive","probabilistic","variables","epistemic","resulting","theoretic","described","usefulness","automatically","naturally","environments","following","experiments","challenging","estimating","extensive","significant","bidirectional","experimental","assumption","estimates","demonstrate","simultaneously","efficient","superiority","approximate","estimation","improvements","variation","minimizing","deblurring","therefore","generalized","framework","improvement","descriptor","performance","gradients","exploiting","detection","histogram","distinguish","introduced","environment","different","geographic","representing","discounting","perception","considered","evidential","contextual","stationary","additional","knowledge","presented","diversity","correlate","available","responses","reference","judgments","evaluating","correlation","currently","generation","translating","sentences","unsupervised","community","reasonable","relevance","expressed","empirical","translation","literature","automated","generalizing","algorithm","functions","optimality","regression","architecture","highlight","indication","measurements","annotations","applications","registered","introduce","integrates","interaction","attention","semantics","predicting","important","empirically","projection","corresponding","trainable","characterization","convolutional","diagnosis","attributes","significance","treatment","augmentation","calcification","establish","determination","appearance","intensity","malignant","concatenated","complementary","dimension","relationship","relations","penalizing","alleviate","technique","computing","limitation","transformations","multivariate","canonical","regularization","statistical","generalization","nonlinear","posterior","approximation","integrated","restricted","differential","distribution","analytically","intractable","advantage","themselves","equations","derivatives","including","determine","promising","processes","variational","tractable","distributed","integrating","contaminated","parameters","observations","facilitate","posteriori","inference","constraint","accurately","performed","consensus","reconstruction","estimated","necessary","comprises","clustering","constraints","localization","extracted","dimensional","reconstruct","extraction","iterative","procedure","promoting","coordinate","regularized","demonstrating","diameters","computations","particular","optimization","multinomial","screening","spherical","regularizations","enforcement","dependencies","relatively","supported","duplicate","declarative","similarity","combining","supporting","representations","classifiers","specifying","resolution","detecting","specification","processing","attribute","conditions","techniques","classification","restoration","maintaining","decimated","modification","reduction","effective","architectures","segmentation","receptive","compression","structure","increasing","inception","generally","prediction","comparable","artifacts","evidences","approaches","toolboxes","directions","supervised","investigate","recognition","particularly","traditional","algorithms","representation","development","resources","intrinsic","delivered","interesting","specifically","autonomous","reflective","principles","gathering","mechanism","recommendation","execution", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	aleatoric
# 	regularizations
# 	nonlinearly
# 	chemometrics
# 	idealized
# 	uncollapsed
# 	integrator
# 	cheminformatics
# 	multipartite
# 	interventional
# 	cytometry
# 	contamination
# 	disaggregate
# 	disaggregation
# 	dependences
# 	representer
# 	waveforms
# 	uncontaminated
# 	disentangles
# 	stragglers
# Some words which never appear in Statistics papers:
# 	deblurring
# 	geographic
# 	evidential
# 	calcification
# 	enforcement
# 	decimated
# 	reflective
# 	subsystems
# 	randomised
# 	harmonics
# 	diffeomorphic
# 	deformation
# 	populated
# 	collapses
# 	demographics
# 	creativity
# 	appearances
# 	regulariser
# 	semisupervised
# 	accordance

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.092911047878263e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7683333333333333
